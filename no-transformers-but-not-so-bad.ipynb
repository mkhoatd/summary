# %%
import os

import textstat
import numpy as np
import pandas as pd


    

def compute_mcrmse(eval_pred):
    """
    Calculates mean columnwise root mean squared error
    https://www.kaggle.com/competitions/commonlit-evaluate-student-summaries/overview/evaluation
    """
    preds, labels = eval_pred

    col_rmse = np.sqrt(np.mean((preds - labels) ** 2, axis=0))
    mcrmse = np.mean(col_rmse)

    return {
        "content_rmse": col_rmse[0],
        "wording_rmse": col_rmse[1],
        "mcrmse": mcrmse,
    }

# %%
prompts_train = pd.read_csv("input/commonlit-evaluate-student-summaries/prompts_train.csv")
prompts_test = pd.read_csv("input/commonlit-evaluate-student-summaries/prompts_test.csv")

summaries_train = pd.read_csv("input/commonlit-evaluate-student-summaries/summaries_train.csv")
summaries_test = pd.read_csv("input/commonlit-evaluate-student-summaries/summaries_test.csv")

sample_submission = pd.read_csv("input/commonlit-evaluate-student-summaries/sample_submission.csv")

prompts_train
# Out:
#   prompt_id                                    prompt_question  \
# 0    39c16e  Summarize at least 3 elements of an ideal trag...
# 1    3b9047  In complete sentences, summarize the structure...
# 2    814d6b  Summarize how the Third Wave developed over su...
# 3    ebad26  Summarize the various ways the factory would u...
#
#                 prompt_title  \
# 0                 On Tragedy
# 1  Egyptian Social Structure
# 2             The Third Wave
# 3    Excerpt from The Jungle
#
#                                          prompt_text
# 0  Chapter 13 \r\nAs the sequel to what has alrea...
# 1  Egyptian society was structured like a pyramid...
# 2  Background \r\nThe Third Wave experiment took ...
# 3  With one member trimming beef in a cannery, an...

# %%
train = summaries_train.merge(prompts_train, how="left", on="prompt_id")
test = summaries_test.merge(prompts_test, how="left", on="prompt_id")

train
# Out:
#         student_id prompt_id  \
# 0     000e8c3c7ddb    814d6b
# 1     0020ae56ffbf    ebad26
# 2     004e978e639e    3b9047
# 3     005ab0199905    3b9047
# 4     0070c9e7af47    814d6b
# ...            ...       ...
# 7160  ff7c7e70df07    ebad26
# 7161  ffc34d056498    3b9047
# 7162  ffd1576d2e1b    3b9047
# 7163  ffe4a98093b2    39c16e
# 7164  fffbccfd8a08    ebad26
#
#                                                    text   content   wording  \
# 0     The third wave was an experimentto see how peo...  0.205683  0.380538
# 1     They would rub it up with soda to make the sme... -0.548304  0.506755
# 2     In Egypt, there were many occupations and soci...  3.128928  4.231226
# 3     The highest class was Pharaohs these people we... -0.210614 -0.471415
# 4     The Third Wave developed  rapidly because the ...  3.272894  3.219757
# ...                                                 ...       ...       ...
# 7160  They used all sorts of chemical concoctions to...  0.205683  0.380538
# 7161  The lowest classes are slaves and farmers slav... -0.308448  0.048171
# 7162             they sorta made people start workin... -1.408180 -0.493603
# 7163  An ideal tragety has three elements that make ... -0.393310  0.627128
# 7164  The meat would smell sour but the would "rub i...  1.771596  0.547742
#
#                                         prompt_question  \
# 0     Summarize how the Third Wave developed over su...
# 1     Summarize the various ways the factory would u...
# 2     In complete sentences, summarize the structure...
# 3     In complete sentences, summarize the structure...
# 4     Summarize how the Third Wave developed over su...
# ...                                                 ...
# 7160  Summarize the various ways the factory would u...
# 7161  In complete sentences, summarize the structure...
# 7162  In complete sentences, summarize the structure...
# 7163  Summarize at least 3 elements of an ideal trag...
# 7164  Summarize the various ways the factory would u...
#
#                    prompt_title  \
# 0                The Third Wave
# 1       Excerpt from The Jungle
# 2     Egyptian Social Structure
# 3     Egyptian Social Structure
# 4                The Third Wave
# ...                         ...
# 7160    Excerpt from The Jungle
# 7161  Egyptian Social Structure
# 7162  Egyptian Social Structure
# 7163                 On Tragedy
# 7164    Excerpt from The Jungle
#
#                                             prompt_text
# 0     Background \r\nThe Third Wave experiment took ...
# 1     With one member trimming beef in a cannery, an...
# 2     Egyptian society was structured like a pyramid...
# 3     Egyptian society was structured like a pyramid...
# 4     Background \r\nThe Third Wave experiment took ...
# ...                                                 ...
# 7160  With one member trimming beef in a cannery, an...
# 7161  Egyptian society was structured like a pyramid...
# 7162  Egyptian society was structured like a pyramid...
# 7163  Chapter 13 \r\nAs the sequel to what has alrea...
# 7164  With one member trimming beef in a cannery, an...
#
# [7165 rows x 8 columns]

# %%
train["is_train"] = 1
test["is_train"] = 0
all_data = pd.concat([train, test])

all_data.sample(10)
# Out:
#         student_id prompt_id  \
# 1483  35825619b6f4    ebad26
# 2158  4cf8fb9d7b2d    39c16e
# 1549  37b0391aaaf2    ebad26
# 4954  aff2c864c54e    39c16e
# 2120  4baa0481f451    39c16e
# 27    01027180ef7c    3b9047
# 773   1bce1188bcdb    ebad26
# 7029  fb1d4fdb9f4c    3b9047
# 3517  7d00ceb28ddb    3b9047
# 1487  35af86bb073b    ebad26
#
#                                                    text   content   wording  \
# 1483  One way is they chop it up in sausages which i... -1.487523 -1.125956
# 2158  An ideal tragedy, as described by Aristotle, p... -0.002466 -0.045439
# 1549  In paragraph 2, it is stated that they used so... -1.427883 -0.790667
# 4954  Three elements of an ideal tragedy, as describ...  0.388379 -0.718005
# 2120  The character cannot be a paragon of good or e...  0.440020  1.133263
# 27        After reading the article I learned about ... -1.114202  0.594411
# 773   They vaaries ways that the factory would usese... -1.264214 -1.505073
# 7029  pharaoh is at top, then noblemen and priests, ... -1.547163 -1.461245
# 3517  The social structure is like a pyramid. The hi... -0.157460 -0.165811
# 1487  There were many way that they hide such as mix... -1.033882 -1.086703
#
#                                         prompt_question  \
# 1483  Summarize the various ways the factory would u...
# 2158  Summarize at least 3 elements of an ideal trag...
# 1549  Summarize the various ways the factory would u...
# 4954  Summarize at least 3 elements of an ideal trag...
# 2120  Summarize at least 3 elements of an ideal trag...
# 27    In complete sentences, summarize the structure...
# 773   Summarize the various ways the factory would u...
# 7029  In complete sentences, summarize the structure...
# 3517  In complete sentences, summarize the structure...
# 1487  Summarize the various ways the factory would u...
#
#                    prompt_title  \
# 1483    Excerpt from The Jungle
# 2158                 On Tragedy
# 1549    Excerpt from The Jungle
# 4954                 On Tragedy
# 2120                 On Tragedy
# 27    Egyptian Social Structure
# 773     Excerpt from The Jungle
# 7029  Egyptian Social Structure
# 3517  Egyptian Social Structure
# 1487    Excerpt from The Jungle
#
#                                             prompt_text  is_train
# 1483  With one member trimming beef in a cannery, an...         1
# 2158  Chapter 13 \r\nAs the sequel to what has alrea...         1
# 1549  With one member trimming beef in a cannery, an...         1
# 4954  Chapter 13 \r\nAs the sequel to what has alrea...         1
# 2120  Chapter 13 \r\nAs the sequel to what has alrea...         1
# 27    Egyptian society was structured like a pyramid...         1
# 773   With one member trimming beef in a cannery, an...         1
# 7029  Egyptian society was structured like a pyramid...         1
# 3517  Egyptian society was structured like a pyramid...         1
# 1487  With one member trimming beef in a cannery, an...         1

# %%
len(all_data)
# Out:
# 7169

# %%
all_data = pd.read_csv('sample.csv')

# %%
(all_data.loc[:, 'content']).std()
# Out:
# 1.0435693830622939

# %%
import textdistance
import tqdm


# textdistance.levenshtein(all_data.iloc[0].text, all_data.iloc[10].text)
# has_almost_duplicate = np.zeros(len(all_data))
# all_data_text = all_data["text"].values
# for i in tqdm.tqdm(range(len(all_data))):
#     for j in range(i+1, len(all_data)):
#         print(f"{j=}")
#         if (has_almost_duplicate[i] != 1 or has_almost_duplicate[j] != 1):
#             text_i = all_data_text[i]
#             text_j = all_data_text[j]
#             ldist = textdistance.levenshtein(text_i, text_j)
#             if ldist < 5:
#                 has_almost_duplicate[i] = 1
#                 has_almost_duplicate[j] = 1
# #                 break
                
# all_data["has_almost_duplicate"] = has_almost_duplicate
train = all_data[all_data["is_train"] == 1]
test = all_data[all_data["is_train"] == 0]

# drop is_train column
train.drop("is_train", axis=1, inplace=True)
test.drop("is_train", axis=1, inplace=True)

train.head()
# Out:
# /tmp/ipykernel_11105/3575158914.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.drop("is_train", axis=1, inplace=True)
# /tmp/ipykernel_11105/3575158914.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.drop("is_train", axis=1, inplace=True)
#      student_id prompt_id                                               text  \
# 0  000e8c3c7ddb    814d6b  The third wave was an experimentto see how peo...
# 1  0020ae56ffbf    ebad26  They would rub it up with soda to make the sme...
# 2  004e978e639e    3b9047  In Egypt, there were many occupations and soci...
# 3  005ab0199905    3b9047  The highest class was Pharaohs these people we...
# 4  0070c9e7af47    814d6b  The Third Wave developed  rapidly because the ...
#
#     content   wording                                    prompt_question  \
# 0  0.205683  0.380538  Summarize how the Third Wave developed over su...
# 1 -0.548304  0.506755  Summarize the various ways the factory would u...
# 2  3.128928  4.231226  In complete sentences, summarize the structure...
# 3 -0.210614 -0.471415  In complete sentences, summarize the structure...
# 4  3.272894  3.219757  Summarize how the Third Wave developed over su...
#
#                 prompt_title  \
# 0             The Third Wave
# 1    Excerpt from The Jungle
# 2  Egyptian Social Structure
# 3  Egyptian Social Structure
# 4             The Third Wave
#
#                                          prompt_text  has_almost_duplicate
# 0  Background \r\nThe Third Wave experiment took ...                   0.0
# 1  With one member trimming beef in a cannery, an...                   0.0
# 2  Egyptian society was structured like a pyramid...                   0.0
# 3  Egyptian society was structured like a pyramid...                   0.0
# 4  Background \r\nThe Third Wave experiment took ...                   0.0

# %%
train = all_data[all_data["is_train"] == 1]
test = all_data[all_data["is_train"] == 0]

# drop is_train column
train.drop("is_train", axis=1, inplace=True)
test.drop("is_train", axis=1, inplace=True)

train.head()
# Out:
# /tmp/ipykernel_11105/1785940852.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.drop("is_train", axis=1, inplace=True)
# /tmp/ipykernel_11105/1785940852.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.drop("is_train", axis=1, inplace=True)
#      student_id prompt_id                                               text  \
# 0  000e8c3c7ddb    814d6b  The third wave was an experimentto see how peo...
# 1  0020ae56ffbf    ebad26  They would rub it up with soda to make the sme...
# 2  004e978e639e    3b9047  In Egypt, there were many occupations and soci...
# 3  005ab0199905    3b9047  The highest class was Pharaohs these people we...
# 4  0070c9e7af47    814d6b  The Third Wave developed  rapidly because the ...
#
#     content   wording                                    prompt_question  \
# 0  0.205683  0.380538  Summarize how the Third Wave developed over su...
# 1 -0.548304  0.506755  Summarize the various ways the factory would u...
# 2  3.128928  4.231226  In complete sentences, summarize the structure...
# 3 -0.210614 -0.471415  In complete sentences, summarize the structure...
# 4  3.272894  3.219757  Summarize how the Third Wave developed over su...
#
#                 prompt_title  \
# 0             The Third Wave
# 1    Excerpt from The Jungle
# 2  Egyptian Social Structure
# 3  Egyptian Social Structure
# 4             The Third Wave
#
#                                          prompt_text  has_almost_duplicate
# 0  Background \r\nThe Third Wave experiment took ...                   0.0
# 1  With one member trimming beef in a cannery, an...                   0.0
# 2  Egyptian society was structured like a pyramid...                   0.0
# 3  Egyptian society was structured like a pyramid...                   0.0
# 4  Background \r\nThe Third Wave experiment took ...                   0.0

# %% [markdown]
# Let's create some features using text statistics and use classic ML algorithm

# %%
import nltk
from nltk.tokenize import word_tokenize


STOPWORDS = pd.read_csv("input/nltk-english-stopwords/nltk_eng_stopwords.csv")["list_of_stopwords"].tolist()
def get_stopwords_rel(text):
    text_words = word_tokenize(text)
    num_stopwords = sum([word in STOPWORDS for word in text_words])
    
    return num_stopwords/len(text_words)

# %%
from tqdm.notebook import tqdm
tqdm.pandas()


def get_stat_features(df, text_col="text"):
    df["num_unique_words"] = df[text_col].progress_apply(lambda x: len(set(x.split())))
    df["num_words"] = df[text_col].progress_apply(lambda x: len(x.split()))
    df["num_sentences"] = df[text_col].progress_apply(lambda x: len(x.split('.')))
    df["isupper"] = df[text_col].progress_apply(lambda x: x[0].isupper())
    df["mean_num_words"] = df[text_col].progress_apply(lambda x: np.mean([len(e.split()) for e in x.split('.')]))
    df["mean_num_unique_words"] = df[text_col].progress_apply(lambda x: np.mean([len(set(e.split())) for e in x.split('.')]))
    df["num_slash"] = df[text_col].progress_apply(lambda x: x.count("\n"))
    df["paragraph_count"] = df[text_col].progress_apply(lambda x: x.count("\n\n"))
    df["upper_count"] = df[text_col].progress_apply(lambda x: np.sum([w.isupper() for w in x.split()])/len(x.split()))
    df["syntax_count"] = df[text_col].progress_apply(lambda x: x.count(",") + x.count("-") + x.count(";") + x.count(":"))
    df["is_end_with_dot"] = df[text_col].progress_apply(lambda x: int(x[-1] == "."))
    df["stopwords_rel"] = df[text_col].progress_apply(lambda x: get_stopwords_rel(x))
    df["lcsstr"] = df.progress_apply(lambda row: textdistance.lcsstr(row.text, row.prompt_text).split().__len__(), axis=1)
    df['automated_readability_index'] = df[text_col].progress_apply(lambda x: textstat.automated_readability_index(x))
    df['coleman_liau_index'] = df[text_col].progress_apply(lambda x: textstat.coleman_liau_index(x))
    df['smog_index'] = df[text_col].progress_apply(lambda x: textstat.smog_index(x))
    df['dale_chall_readability_score'] = df[text_col].progress_apply(lambda x: textstat.dale_chall_readability_score(x))
    df['linsear_write_formula'] = df[text_col].progress_apply(lambda x: textstat.linsear_write_formula(x))
    df['gunning_fog'] = df[text_col].progress_apply(lambda x: textstat.gunning_fog(x))
    df['text_standard_float'] = df[text_col].progress_apply(lambda x: textstat.text_standard(x, float_output=True))
    df['spache_readability'] = df[text_col].progress_apply(lambda x: textstat.spache_readability(x))
    df['rix'] = df[text_col].progress_apply(lambda x: textstat.rix(x))
    df['lix'] = df[text_col].progress_apply(lambda x: textstat.lix(x))

    return df
    
train_feat = get_stat_features(train)
test_feat = get_stat_features(test)
# Out:
#   0%|          | 0/7165 [00:00<?, ?it/s]
# /tmp/ipykernel_11105/3759327414.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num_unique_words"] = df[text_col].progress_apply(lambda x: len(set(x.split())))
#   0%|          | 0/7165 [00:00<?, ?it/s]
# /tmp/ipykernel_11105/3759327414.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num_words"] = df[text_col].progress_apply(lambda x: len(x.split()))
#   0%|          | 0/7165 [00:00<?, ?it/s]
# /tmp/ipykernel_11105/3759327414.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num_sentences"] = df[text_col].progress_apply(lambda x: len(x.split('.')))
#   0%|          | 0/7165 [00:00<?, ?it/s]
# /tmp/ipykernel_11105/3759327414.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["isupper"] = df[text_col].progress_apply(lambda x: x[0].isupper())
#   0%|          | 0/7165 [00:00<?, ?it/s]
# /tmp/ipykernel_11105/3759327414.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["mean_num_words"] = df[text_col].progress_apply(lambda x: np.mean([len(e.split()) for e in x.split('.')]))
#   0%|          | 0/7165 [00:00<?, ?it/s]
# /tmp/ipykernel_11105/3759327414.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["mean_num_unique_words"] = df[text_col].progress_apply(lambda x: np.mean([len(set(e.split())) for e in x.split('.')]))
#   0%|          | 0/7165 [00:00<?, ?it/s]
# /tmp/ipykernel_11105/3759327414.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num_slash"] = df[text_col].progress_apply(lambda x: x.count("\n"))
#   0%|          | 0/7165 [00:00<?, ?it/s]
# /tmp/ipykernel_11105/3759327414.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["paragraph_count"] = df[text_col].progress_apply(lambda x: x.count("\n\n"))
#   0%|          | 0/7165 [00:00<?, ?it/s]
# /tmp/ipykernel_11105/3759327414.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["upper_count"] = df[text_col].progress_apply(lambda x: np.sum([w.isupper() for w in x.split()])/len(x.split()))
#   0%|          | 0/7165 [00:00<?, ?it/s]
# /tmp/ipykernel_11105/3759327414.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["syntax_count"] = df[text_col].progress_apply(lambda x: x.count(",") + x.count("-") + x.count(";") + x.count(":"))
#   0%|          | 0/7165 [00:00<?, ?it/s]
# /tmp/ipykernel_11105/3759327414.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["is_end_with_dot"] = df[text_col].progress_apply(lambda x: int(x[-1] == "."))
#   0%|          | 0/7165 [00:00<?, ?it/s]
# /tmp/ipykernel_11105/3759327414.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["stopwords_rel"] = df[text_col].progress_apply(lambda x: get_stopwords_rel(x))
#   0%|          | 0/7165 [00:00<?, ?it/s]

# %% [markdown]
# Let's see corr matrix:

# %%
NO_FEATURES = ["student_id", "prompt_id", "prompt_question", "prompt_title", "prompt_text", "text"]
TARGETS = ["content", "wording"]
FEATURES = [col for col in train.columns if col not in NO_FEATURES + TARGETS]

corr = train_feat[TARGETS + FEATURES].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_733cb_row0_col0, #T_733cb_row1_col1, #T_733cb_row2_col2, #T_733cb_row3_col3, #T_733cb_row4_col4, #T_733cb_row5_col5, #T_733cb_row6_col6, #T_733cb_row7_col7, #T_733cb_row8_col8, #T_733cb_row9_col9, #T_733cb_row10_col10, #T_733cb_row11_col11, #T_733cb_row12_col12, #T_733cb_row13_col13, #T_733cb_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_733cb_row0_col1, #T_733cb_row1_col0 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_733cb_row0_col2, #T_733cb_row3_col11, #T_733cb_row7_col5, #T_733cb_row14_col9, #T_733cb_row14_col11 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_733cb_row0_col3 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_733cb_row0_col4 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_733cb_row0_col5 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_733cb_row0_col6 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_733cb_row0_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_733cb_row0_col8 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_733cb_row0_col9, #T_733cb_row7_col10, #T_733cb_row8_col5, #T_733cb_row8_col10, #T_733cb_row12_col14, #T_733cb_row13_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_733cb_row0_col10, #T_733cb_row1_col11, #T_733cb_row2_col4, #T_733cb_row4_col11 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_733cb_row0_col11, #T_733cb_row1_col2, #T_733cb_row1_col9, #T_733cb_row1_col10, #T_733cb_row2_col1, #T_733cb_row5_col7, #T_733cb_row5_col8, #T_733cb_row5_col14, #T_733cb_row8_col13, #T_733cb_row14_col0, #T_733cb_row14_col3, #T_733cb_row14_col4, #T_733cb_row14_col5, #T_733cb_row14_col6, #T_733cb_row14_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_733cb_row0_col12 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_733cb_row0_col13, #T_733cb_row2_col8, #T_733cb_row9_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_733cb_row0_col14, #T_733cb_row8_col1, #T_733cb_row10_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_733cb_row1_col3 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_733cb_row1_col4, #T_733cb_row1_col5 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_733cb_row1_col6, #T_733cb_row7_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_733cb_row1_col7, #T_733cb_row4_col14, #T_733cb_row11_col7 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_733cb_row1_col8, #T_733cb_row10_col7, #T_733cb_row10_col14, #T_733cb_row11_col12 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_733cb_row1_col12 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_733cb_row1_col13, #T_733cb_row13_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_733cb_row1_col14, #T_733cb_row2_col13, #T_733cb_row6_col3 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_733cb_row2_col0, #T_733cb_row6_col9, #T_733cb_row7_col13, #T_733cb_row11_col4, #T_733cb_row13_col8 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_733cb_row2_col3, #T_733cb_row11_col3, #T_733cb_row13_col11, #T_733cb_row14_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_733cb_row2_col5, #T_733cb_row2_col14, #T_733cb_row14_col13 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_733cb_row2_col6, #T_733cb_row6_col7, #T_733cb_row6_col14, #T_733cb_row13_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_733cb_row2_col7, #T_733cb_row5_col13, #T_733cb_row10_col12, #T_733cb_row11_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_733cb_row2_col9, #T_733cb_row6_col2, #T_733cb_row9_col4 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_733cb_row2_col10, #T_733cb_row10_col1, #T_733cb_row13_col3 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_733cb_row2_col11, #T_733cb_row3_col10, #T_733cb_row11_col9 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_733cb_row2_col12, #T_733cb_row6_col12, #T_733cb_row9_col12 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_733cb_row3_col0 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_733cb_row3_col1 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_733cb_row3_col2, #T_733cb_row3_col9, #T_733cb_row5_col9, #T_733cb_row10_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_733cb_row3_col4, #T_733cb_row4_col3 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_733cb_row3_col5, #T_733cb_row9_col10, #T_733cb_row10_col9 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_733cb_row3_col6, #T_733cb_row7_col0, #T_733cb_row9_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_733cb_row3_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_733cb_row3_col8, #T_733cb_row4_col8 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_733cb_row3_col12, #T_733cb_row5_col3 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_733cb_row3_col13, #T_733cb_row4_col13, #T_733cb_row10_col13, #T_733cb_row11_col6, #T_733cb_row12_col6 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_733cb_row3_col14 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_733cb_row4_col0, #T_733cb_row4_col5 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_733cb_row4_col1, #T_733cb_row12_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_733cb_row4_col2, #T_733cb_row4_col9, #T_733cb_row5_col2, #T_733cb_row7_col1, #T_733cb_row11_col0, #T_733cb_row14_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_733cb_row4_col6, #T_733cb_row13_col6 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_733cb_row4_col7 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_733cb_row4_col10 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_733cb_row4_col12 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_733cb_row5_col0 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_733cb_row5_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_733cb_row5_col4 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_733cb_row5_col6 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_733cb_row5_col10, #T_733cb_row5_col11, #T_733cb_row10_col11, #T_733cb_row12_col10 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_733cb_row5_col12 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_733cb_row6_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_733cb_row6_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_733cb_row6_col4, #T_733cb_row8_col2, #T_733cb_row10_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_733cb_row6_col5, #T_733cb_row7_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_733cb_row6_col8, #T_733cb_row9_col0, #T_733cb_row10_col0, #T_733cb_row11_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_733cb_row6_col10, #T_733cb_row8_col6, #T_733cb_row11_col10 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_733cb_row6_col11 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_733cb_row6_col13 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_733cb_row7_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_733cb_row7_col6, #T_733cb_row7_col11, #T_733cb_row8_col11, #T_733cb_row13_col10, #T_733cb_row14_col10 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_733cb_row7_col8, #T_733cb_row8_col7 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_733cb_row7_col9, #T_733cb_row8_col9, #T_733cb_row13_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_733cb_row7_col12 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_733cb_row7_col14 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_733cb_row8_col0, #T_733cb_row9_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_733cb_row8_col3 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_733cb_row8_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_733cb_row8_col12 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_733cb_row8_col14 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_733cb_row9_col1, #T_733cb_row11_col1, #T_733cb_row12_col9 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_733cb_row9_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_733cb_row9_col3 {
#   background-color: #5f7fe

# %% [markdown]
# Learning catboost and check metric:

# %%
from sklearn.model_selection import GroupKFold
from catboost import CatBoostRegressor


gfk = GroupKFold(n_splits=4)
train_oof = np.zeros((len(train_feat), 2))
test_pred = np.zeros((len(test_feat), 2))
X, y = train[FEATURES], train[TARGETS]
for train_index, val_index in gfk.split(train_feat, groups=train_feat["prompt_id"]):
    X_train, y_train = X.iloc[train_index], y.iloc[train_index]
    X_val, y_val = X.iloc[val_index], y.iloc[val_index]
    
    model = CatBoostRegressor(random_state=42, max_depth=4, 
                              objective="MultiRMSE")
    model.fit(X_train, y_train, eval_set=(X_val, y_val), metric_period=100)
    
    train_oof[val_index] = model.predict(X_val)
    test_pred +=  model.predict(test[FEATURES])/4
# Out:
# 0:	learn: 1.4609067	test: 1.4214483	best: 1.4214483 (0)	total: 1.49ms	remaining: 1.49s
# 100:	learn: 0.9446117	test: 0.8770675	best: 0.8770675 (100)	total: 164ms	remaining: 1.46s
# 200:	learn: 0.9147492	test: 0.8551387	best: 0.8551387 (200)	total: 339ms	remaining: 1.35s
# 300:	learn: 0.8993352	test: 0.8511568	best: 0.8511568 (300)	total: 485ms	remaining: 1.13s
# 400:	learn: 0.8864320	test: 0.8486393	best: 0.8486393 (400)	total: 633ms	remaining: 946ms
# 500:	learn: 0.8764329	test: 0.8495621	best: 0.8486393 (400)	total: 767ms	remaining: 764ms
# 600:	learn: 0.8683174	test: 0.8503087	best: 0.8486393 (400)	total: 890ms	remaining: 591ms
# 700:	learn: 0.8609089	test: 0.8501671	best: 0.8486393 (400)	total: 1.02s	remaining: 434ms
# 800:	learn: 0.8547572	test: 0.8506058	best: 0.8486393 (400)	total: 1.14s	remaining: 283ms
# 900:	learn: 0.8482012	test: 0.8510134	best: 0.8486393 (400)	total: 1.28s	remaining: 141ms
# 999:	learn: 0.8418819	test: 0.8511304	best: 0.8486393 (400)	total: 1.45s	remaining: 0us
#
# bestTest = 0.8486393381
# bestIteration = 400
#
# Shrink model to first 401 iterations.
# 0:	learn: 1.4505766	test: 1.4369245	best: 1.4369245 (0)	total: 1.44ms	remaining: 1.44s
# 100:	learn: 0.8892297	test: 0.9899277	best: 0.9899277 (100)	total: 129ms	remaining: 1.15s
# 200:	learn: 0.8519440	test: 1.0177254	best: 0.9899277 (100)	total: 245ms	remaining: 973ms
# 300:	learn: 0.8368407	test: 1.0313204	best: 0.9899277 (100)	total: 354ms	remaining: 821ms
# 400:	learn: 0.8252834	test: 1.0394077	best: 0.9899277 (100)	total: 476ms	remaining: 712ms
# 500:	learn: 0.8160350	test: 1.0471062	best: 0.9899277 (100)	total: 585ms	remaining: 583ms
# 600:	learn: 0.8081449	test: 1.0504159	best: 0.9899277 (100)	total: 713ms	remaining: 473ms
# 700:	learn: 0.8011618	test: 1.0536937	best: 0.9899277 (100)	total: 824ms	remaining: 351ms
# 800:	learn: 0.7948569	test: 1.0546293	best: 0.9899277 (100)	total: 934ms	remaining: 232ms
# 900:	learn: 0.7885595	test: 1.0562680	best: 0.9899277 (100)	total: 1.04s	remaining: 115ms
# 999:	learn: 0.7834978	test: 1.0576292	best: 0.9899277 (100)	total: 1.16s	remaining: 0us
#
# bestTest = 0.9899277269
# bestIteration = 100
#
# Shrink model to first 101 iterations.
# 0:	learn: 1.4765694	test: 1.3788177	best: 1.3788177 (0)	total: 1.52ms	remaining: 1.52s
# 100:	learn: 0.9121445	test: 1.0094310	best: 1.0094310 (100)	total: 117ms	remaining: 1.04s
# 200:	learn: 0.8854030	test: 1.0314458	best: 1.0094310 (100)	total: 243ms	remaining: 965ms
# 300:	learn: 0.8736067	test: 1.0375385	best: 1.0094310 (100)	total: 357ms	remaining: 830ms
# 400:	learn: 0.8622088	test: 1.0394490	best: 1.0094310 (100)	total: 477ms	remaining: 712ms
# 500:	learn: 0.8527994	test: 1.0407392	best: 1.0094310 (100)	total: 600ms	remaining: 597ms
# 600:	learn: 0.8444652	test: 1.0432689	best: 1.0094310 (100)	total: 718ms	remaining: 477ms
# 700:	learn: 0.8371764	test: 1.0451537	best: 1.0094310 (100)	total: 837ms	remaining: 357ms
# 800:	learn: 0.8307291	test: 1.0476754	best: 1.0094310 (100)	total: 956ms	remaining: 238ms
# 900:	learn: 0.8239659	test: 1.0486112	best: 1.0094310 (100)	total: 1.07s	remaining: 118ms
# 999:	learn: 0.8177254	test: 1.0499313	best: 1.0094310 (100)	total: 1.19s	remaining: 0us
#
# bestTest = 1.009430955
# bestIteration = 100
#
# Shrink model to first 101 iterations.
# 0:	learn: 1.4004493	test: 1.7120437	best: 1.7120437 (0)	total: 1.22ms	remaining: 1.21s
# 100:	learn: 0.8759051	test: 1.1880796	best: 1.1880796 (100)	total: 115ms	remaining: 1.02s
# 200:	learn: 0.8494120	test: 1.1539286	best: 1.1539286 (200)	total: 245ms	remaining: 974ms
# 300:	learn: 0.8368530	test: 1.1397695	best: 1.1397695 (300)	total: 371ms	remaining: 860ms
# 400:	learn: 0.8258470	test: 1.1311592	best: 1.1311592 (400)	total: 487ms	remaining: 727ms
# 500:	learn: 0.8169780	test: 1.1269161	best: 1.1269161 (500)	total: 602ms	remaining: 599ms
# 600:	learn: 0.8090081	test: 1.1246474	best: 1.1246474 (600)	total: 723ms	remaining: 480ms
# 700:	learn: 0.8022738	test: 1.1231383	best: 1.1231383 (700)	total: 844ms	remaining: 360ms
# 800:	learn: 0.7959329	test: 1.1223993	best: 1.1223993 (800)	total: 969ms	remaining: 241ms
# 900:	learn: 0.7904941	test: 1.1226308	best: 1.1223993 (800)	total: 1.08s	remaining: 119ms
# 999:	learn: 0.7851065	test: 1.1224796	best: 1.1223993 (800)	total: 1.2s	remaining: 0us
#
# bestTest = 1.12239928
# bestIteration = 800
#
# Shrink model to first 801 iterations.

# %% [markdown]
# Checking competition metric:

# %%
compute_mcrmse((train_oof, train[TARGETS]))
# Out:
# /tmp/ipykernel_11105/3174358984.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   "content_rmse": col_rmse[0],
# /tmp/ipykernel_11105/3174358984.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   "wording_rmse": col_rmse[1],
# {'content_rmse': 0.5393559394901973,
#  'wording_rmse': 0.8175663748779349,
#  'mcrmse': 0.6784611571840662}

# %% [markdown]
# Not bad!We need submit it!

# %%
test
# Out:
#         student_id prompt_id            text  content  wording  \
# 7165  000000ffffff    abc123  Example text 1      NaN      NaN
# 7166  111111eeeeee    def789  Example text 2      NaN      NaN
# 7167  222222cccccc    abc123  Example text 3      NaN      NaN
# 7168  333333dddddd    def789  Example text 4      NaN      NaN
#
#      prompt_question     prompt_title       prompt_text  has_almost_duplicate  \
# 7165    Summarize...  Example Title 1  Heading\nText...                   1.0
# 7166    Summarize...  Example Title 2  Heading\nText...                   1.0
# 7167    Summarize...  Example Title 1  Heading\nText...                   1.0
# 7168    Summarize...  Example Title 2  Heading\nText...                   1.0
#
#       num_unique_words  ...  num_sentences  isupper  mean_num_words  \
# 7165                 3  ...              1     True             3.0
# 7166                 3  ...              1     True             3.0
# 7167                 3  ...              1     True             3.0
# 7168                 3  ...              1     True             3.0
#
#       mean_num_unique_words  num_slash  paragraph_count  upper_count  \
# 7165                    3.0          0                0          0.0
# 7166                    3.0          0                0          0.0
# 7167                    3.0          0                0          0.0
# 7168                    3.0          0                0          0.0
#
#       syntax_count  is_end_with_dot  stopwords_rel
# 7165             0                0            0.0
# 7166             0                0            0.0
# 7167             0                0            0.0
# 7168             0                0            0.0
#
# [4 rows x 21 columns]

# %%
sample_submission["content"] = test_pred[:, 0]
sample_submission["wording"] = test_pred[:, 1]

sample_submission.to_csv("submission.csv", index=False)

# %% [markdown]
# The main idea of this notebook, inspire comunity to not only train transformers, but to find new interesting solutions!
